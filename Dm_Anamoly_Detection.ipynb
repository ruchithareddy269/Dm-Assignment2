# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchithareddy269/Dm-Assignment2/blob/main/Dm_Anamoly_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.5 MB/s eta 0:00:00
# ...

# %%
# check intalled version
import pycaret
print(pycaret.__version__)
# Out:
# 3.1.0

# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#loading the data
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/DM-Assignment-2-part2/creditcard.csv', usecols=['Time','V7'])
data
# Out:
#     Time        V7
# 0      0  0.239599
# 1      0 -0.078803
# 2      1  0.791461
# 3      1  0.237609
# 4      2  0.592941
# 5      2  0.476201
# 6      4 -0.005159
# 7      7  1.120631
# 8      7  0.370145
# 9      9  0.651583
# 10    10 -1.423236
# 11    10  0.470455
# 12    10 -0.689405
# 13    11 -0.096717
# 14    12 -0.422911
# 15    12 -0.608581
# 16    12 -0.586057
# 17    13  0.707642
# 18    14 -1.559738
# 19    15 -1.080664
# 20    16 -0.878586
# 21    17  0.107712
# 22    18  0.241147
# 23    18 -0.946365
# 24    22 -0.063063
# 25    22  0.543985
# 26    23  0.369025
# 27    23 -0.264905
# 28    23  0.740228
# 29    23 -0.767084
# 30    24  0.006494
# 31    25 -0.118760
# 32    26  0.711206
# 33    26  0.711206
# 34    26  0.693039

# %%
data1=data.sample(frac=0.95, random_state=786).reset_index(drop=True)
data_unseen=data.drop(data.index).reset_index(drop=True)

print('Modeling data: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Modeling data: (35, 2)
# Unseen Data For Predictions: (0, 2)

# %%
from pycaret.anomaly import *

# %%
exp1=setup(data, normalize = True, ignore_features = ['V5'],
                   session_id = 150)
# Out:
# <style type="text/css">
# #T_e1192_row5_col1, #T_e1192_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1192" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1192_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1192_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1192_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1192_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1192_row0_col1" class="data row0 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_e1192_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1192_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e1192_row1_col1" class="data row1 col1" >(35, 2)</td>
#     </tr>
#     <tr>
# ...

# %%
#create a model
iforest=create_model('iforest')
iforest
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# IForest(behaviour='new', bootstrap=False, contamination=0.05,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=150, verbose=0)

# %%
#here we have created a model and we would like to assign the anomaly labels to our dataset, so we will use the assign_model() now.
iforest_results = assign_model(iforest)
iforest_results.head()
# Out:
#    Time        V7  Anomaly  Anomaly_Score
# 0     0  0.239599        0      -0.083079
# 1     0 -0.078803        0      -0.050936
# 2     1  0.791461        0      -0.055622
# 3     1  0.237609        0      -0.113039
# 4     2  0.592941        0      -0.115901
