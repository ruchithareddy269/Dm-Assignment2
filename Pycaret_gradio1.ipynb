# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchithareddy269/Dm-Assignment2/blob/main/Pycaret_gradio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##python+Gradio demo-1
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.0 MB/s eta 0:00:00
# ...

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 6.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 7.6 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
data=get_data('germany')
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#        InvoiceDate  UnitPrice  CustomerID  Country
# 0  12/1/2010 13:04       2.95       12662  Germany
# 1  12/1/2010 13:04       2.55       12662  Germany
# 2  12/1/2010 13:04       0.85       12662  Germany
# 3  12/1/2010 13:04       1.65       12662  Germany
# 4  12/1/2010 13:04       1.95       12662  Germany

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#        InvoiceDate  UnitPrice  CustomerID  Country
# 0  12/1/2010 13:04       2.95       12662  Germany
# 1  12/1/2010 13:04       2.55       12662  Germany
# 2  12/1/2010 13:04       0.85       12662  Germany
# 3  12/1/2010 13:04       1.65       12662  Germany
# 4  12/1/2010 13:04       1.95       12662  Germany

# %%
from pycaret.classification import *

# %%
e1=setup(data,target='Country',session_id=150)
# Out:
# <style type="text/css">
# #T_6fca0_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6fca0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fca0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6fca0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fca0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fca0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6fca0_row0_col1" class="data row0 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_6fca0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fca0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6fca0_row1_col1" class="data row1 col1" >Country</td>
#     </tr>
#     <tr>
#       <th id="T_6fca0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lightgbm=create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_3e3c9_row10_col0, #T_3e3c9_row10_col1, #T_3e3c9_row10_col2, #T_3e3c9_row10_col3, #T_3e3c9_row10_col4, #T_3e3c9_row10_col5, #T_3e3c9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3e3c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e3c9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3e3c9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3e3c9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3e3c9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3e3c9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3e3c9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3e3c9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
create_app(lightgbm)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ![gradio1-image.jpeg](data:image/jpeg;base64,...)
