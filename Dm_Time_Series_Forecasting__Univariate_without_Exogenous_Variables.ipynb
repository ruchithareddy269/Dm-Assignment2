# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchithareddy269/Dm-Assignment2/blob/main/Dm_Time_Series_Forecasting__Univariate_without_Exogenous_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 73.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 77.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
from pycaret.datasets import get_data
from pycaret.time_series import TSForecastingExperiment

# %%
x=get_data('airline', verbose=False)

# %%
fh=10
e1=TSForecastingExperiment()
e1.setup(data=x,fh=fh,fig_kwargs=fig_kwargs)
# Out:
# <style type="text/css">
# #T_b9224_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b9224" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9224_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b9224_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9224_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9224_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b9224_row0_col1" class="data row0 col1" >2722</td>
#     </tr>
#     <tr>
#       <th id="T_b9224_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9224_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b9224_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
# ...

# %%
e1.plot_model()

# %%
e1.plot_model(data_kwargs={"plot_data_type":["original", "imputed", "transformed"]})

# %%
e1.plot_model(plot="pacf", data_kwargs={'nlags':40}, fig_kwargs={'height':350, "width":700})

# %%
e1.plot_model(plot="diagnostics", fig_kwargs={"height":400,"width":600})

# %%
e1.plot_model(plot="diff",data_kwargs={"lags_list":[[3], [1,3]], "acf": True, "pacf": True},
    fig_kwargs={"height":500, "width":1200}
)

# %%
#statistics
e1.check_stats(test="summary")
# Out:
#       Test   Test Name         Data            Property Setting         Value
# 0  Summary  Statistics  Transformed              Length            144.000000
# 1  Summary  Statistics  Transformed    # Missing Values              0.000000
# 2  Summary  Statistics  Transformed                Mean            280.298611
# 3  Summary  Statistics  Transformed              Median            265.500000
# 4  Summary  Statistics  Transformed  Standard Deviation            119.966317
# 5  Summary  Statistics  Transformed            Variance          14391.917201
# 6  Summary  Statistics  Transformed            Kurtosis             -0.364942
# 7  Summary  Statistics  Transformed            Skewness              0.583160
# 8  Summary  Statistics  Transformed   # Distinct Values            118.000000

# %%
e1.check_stats(test='white_noise')
# Out:
#           Test  Test Name         Data        Property  \
# 0  White Noise  Ljung-Box  Transformed  Test Statictic
# 1  White Noise  Ljung-Box  Transformed  Test Statictic
# 2  White Noise  Ljung-Box  Transformed         p-value
# 3  White Noise  Ljung-Box  Transformed         p-value
# 4  White Noise  Ljung-Box  Transformed     White Noise
# 5  White Noise  Ljung-Box  Transformed     White Noise
#
#                     Setting        Value
# 0  {'alpha': 0.05, 'K': 24}  1606.083817
# 1  {'alpha': 0.05, 'K': 48}  1933.155822
# 2  {'alpha': 0.05, 'K': 24}          0.0
# 3  {'alpha': 0.05, 'K': 48}          0.0
# 4  {'alpha': 0.05, 'K': 24}        False
# 5  {'alpha': 0.05, 'K': 48}        False
